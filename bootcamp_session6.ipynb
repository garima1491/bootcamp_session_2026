# %% [markdown]
# <a href="https://colab.research.google.com/github/garima1491/bootcamp_session_2026/blob/main/bootcamp_session6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Machine learning improves by measuring error and correcting itself step by step.


#Features
#label
#prediction problem
#conclusion from visible data


#classification- it mean are classifying an object
#regression- to predict a continuous problem


#Face unlock-- classification
#predicting land prices-- regression
#google photos use what to define faces-- classification
#weather forecast-- regression

#classification:

#student results--
JEE MAINS (marks to rank)

XYZ-marks--2

#feature
percentile
score
rank
category
study hours per day
no of questions attempted
shifts
no students attempted
difficulty level of shift

percentile- raw marks


#colour difference
#position
